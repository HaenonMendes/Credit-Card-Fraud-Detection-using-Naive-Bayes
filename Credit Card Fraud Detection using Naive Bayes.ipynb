# %%
# Credit Card Fraud Detection using Naive Bayes

# %%
# Importing the relevant libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Importing the dataset

creditcard_fraud = pd.read_csv("creditcard.csv")

# %%
creditcard_fraud.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
creditcard_fraud.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
creditcard_fraud.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
creditcard_fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# Visualizing the dataset

# %%
noncredit_fraud = creditcard_fraud[creditcard_fraud['Class']==0]

# %%
credit_fraud = creditcard_fraud[creditcard_fraud['Class']==1]

# %%
credit_fraud
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
noncredit_fraud
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
print( 'Percent of Fraud Transactions =', (len(credit_fraud) / len(creditcard_fraud) )*100,"%")
# Out:
# Percent of Fraud Transactions = 0.1727485630620034 %

# %%
sns.countplot(creditcard_fraud['Class'], label = "Count")

# %%
# From the above plot, we see that the data is unbanlanced

# %%
plt.figure(figsize=(30,10)) 
sns.heatmap(creditcard_fraud.corr(), annot=True)

# %%
# Most of the dataset is uncorrelated, its probably because the data is a result of Principal Componenet Analysis (PCA)
# Features V1 to V28 are Principal Components resulted after propagating real features through PCA.

# %%
column_head = creditcard_fraud.columns.values

# %%
# kernel density estimation (KDE) is a non-parametric way to estimate the probability density function of a random variable.
i = 1

fig, ax = plt.subplots(8,4,figsize=(18,30))
for column_header in column_head:    
    plt.subplot(8,4,i)
    sns.kdeplot(credit_fraud[column_header], bw = 0.4, label = "CreditFraud", shade=True, color="r", linestyle="--")
    sns.kdeplot(noncredit_fraud[column_header], bw = 0.4, label = "Non-Credit Fraud", shade=True, color= "y", linestyle=":")
    plt.title(column_header, fontsize=12)
    i = i + 1
plt.show();
# Out:
# C:\Users\Hansen\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Hansen\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
# Now we create the train and test datasets

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
creditcard_fraud['Amount_Norm'] = sc.fit_transform(creditcard_fraud['Amount'].values.reshape(-1,1))

# %%
creditcard_fraud.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739  ...  0.798278 -0.137458  0.141267 -0.206010  0.502292
#
# ...

# %%
creditcard_fraud = creditcard_fraud.drop(['Amount'], axis = 1)

# %%
# Dropping the target label coloumns
X = creditcard_fraud.drop(['Class'],axis=1)
y = creditcard_fraud['Class']

# %%
X.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V20       V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Now we train the model

# %%
X_train.shape
# Out:
# (227845, 30)

# %%
y_train.shape
# Out:
# (227845,)

# %%
X_test.shape
# Out:
# (56962, 30)

# %%
y_test.shape
# Out:
# (56962,)

# %%
from sklearn.naive_bayes import GaussianNB 
Naive_Bayes_classifier = GaussianNB()
Naive_Bayes_classifier.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
# Now we evaluate the model

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
y_predict_train = Naive_Bayes_classifier.predict(X_train)
y_predict_train
cm = confusion_matrix(y_train, y_predict_train)
sns.heatmap(cm, annot=True)

# %%
# Predicting the Test set results
y_predict_test = Naive_Bayes_classifier.predict(X_test)
cm = confusion_matrix(y_test, y_predict_test)
sns.heatmap(cm, annot=True)

# %%
print(classification_report(y_test, y_predict_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56863
#            1       0.16      0.69      0.26        99
#
#     accuracy                           0.99     56962
#    macro avg       0.58      0.84      0.63     56962
# weighted avg       1.00      0.99      1.00     56962

# %%
# We can still improve the model

# %%
X = creditcard_fraud.drop(['Time','V8','V13','V15','V20','V22','V23','V24','V25','V26','V27','V28','Class'], axis = 1)

# %%
X.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V9       V10       V11       V12       V14       V16       V17  \
# 0  0.363787  0.090794 -0.551600 -0.617801 -0.311169 -0.470401  0.207971
# 1 -0.255425 -0.166974  1.612727  1.065235 -0.143772  0.463917 -0.114805
# 2 -1.514654  0.207643  0.624501  0.066084 -0.165946 -2.890083  1.109969
# 3 -1.387024 -0.054952 -0.226487  0.178228 -0.287924 -1.059647 -0.684093
# 4  0.817739  0.753074 -0.822843  0.538196 -1.119670 -0.451449 -0.237033
#
#         V18       V19       V21  Amount_Norm
# 0  0.025791  0.403993 -0.018307     0.244964
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
Naive_Bayes_classifier = GaussianNB()
Naive_Bayes_classifier.fit(X_train, y_train)
y_predict = Naive_Bayes_classifier.predict(X_test)
cm = confusion_matrix(y_test, y_predict)
sns.heatmap(cm, annot=True)

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56888
#            1       0.07      0.82      0.12        74
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.90      0.56     56962
# weighted avg       1.00      0.98      0.99     56962

# %%
print("Number of fraud points in the testing dataset = ", sum(y_test))
# Out:
# Number of fraud points in the testing dataset =  74
